# %%
from sqlalchemy import create_engine
from sqlalchemy.ext.declarative import declarative_base

db_string = "postgresql://wbauer_adb:adb2020@pgsql-196447.vipserv.org:5432/wbauer_adb"
engine = create_engine(db_string)
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Date, ForeignKey, CheckConstraint, UniqueConstraint

# %% [markdown]
# Defining SQL database schema with constraints

# %%
class Game(Base):
    __tablename__ = 'games'
    __table_args__ = (
        CheckConstraint('winner_pts > 0'),
        CheckConstraint('loser_pts > 0')
    )
    id = Column(Integer, primary_key=True)
    date = Column(Date, nullable=False)
    sb = Column(String(50))
    winner_id = Column(Integer, ForeignKey('teams.id'))
    winner_pts = Column(Integer, nullable=False)
    loser_id = Column(Integer, ForeignKey('teams.id'))
    loser_pts = Column(Integer, nullable=False)
    mvp_id = Column(Integer, ForeignKey('players.id'))
    stadium_id = Column(Integer, ForeignKey('stadiums.id'))
    
class Team(Base):
    __tablename__ = 'teams'
    __table_args__ = (
        UniqueConstraint('name'),
    )
    id = Column(Integer, primary_key=True)
    name = Column(String(50), nullable=False)
    
class Player(Base):
    __tablename__ = 'players'
    id = Column(Integer, primary_key=True)
    full_name = Column(String(50), nullable=False)
    
class Stadium(Base):
    __tablename__ = 'stadiums'
    id = Column(Integer, primary_key=True)
    name = Column(String(50), nullable=False)
    city_id = Column(Integer, ForeignKey('cities.id'))
    
class City(Base):
    __tablename__ = 'cities'
    id = Column(Integer, primary_key=True)
    name = Column(String(50), nullable=False)
    state_id = Column(Integer, ForeignKey('states.id'))
    
class State(Base):
    __tablename__ = 'states'
    __table_args__ = (
        UniqueConstraint('name'),
    )
    id = Column(Integer, primary_key=True)
    name = Column(String(50), nullable=False)
    
Base.metadata.create_all(engine)

# %% [markdown]
# Describing database in POSTGRESQL language
# CREATE TABLE games(
#     id serial PRIMARY KEY,
#     date DATE NOT NULL,
#     sb VARCHAR(50),
#     winner_id integer NOT NULL,
#     winner_pts integer NOT NULL,
#     loser_id integer NOT NULL,
#     loser_pts integer NOT_NULL,
#     mvp_id integer NOT NULL,
#     stadium_id integer NOT NULL
#     CONSTRAINT games_winner_id_fkey FOREIGN KEY (winner_id)
#         REFERNCES teams(id) MATCH SIMPLE
#         ON UPDATE NO ACTION ON DELETE NO ACTION,
#     CONSTRAINT games_loser_id_fkey FOREIGN KEY (loser_id)
#         REFERNCES teams (id) MATCH SIMPLE
#         ON UPDATE NO ACTION ON DELETE NO ACTION,
#     CONSTRAINT games_mvp_id_fkey FOREIGN KEY (mvp_id)
#         REFERNCES players (id) MATCH SIMPLE
#         ON UPDATE NO ACTION ON DELETE NO ACTION,
#     CONSTRAINT games_id_fkey FOREIGN KEY (stadium_id)
#         REFERNCES stadiums (id) MATCH SIMPLE
#         ON UPDATE NO ACTION ON DELETE NO ACTION
# )
#
# CREATE TABLE teams(
#     id serial PRIMARY KEY,
#     full_name VARCHAR(50) UNIQUE NOT NULL,
# )
#
# CREATE TABLE players(
#     id serial PRIMARY KEY,
#     full_name VARCHAR(50) NOT NULL
# )
#
# CREATE TABLE stadiums(
#     id series PRIMARY KEY,
#     name VARCHAR(50),
#     city_id integer NOT NULL,
#     CONSTRAINT stadiums_city_id_fkey FOREIGN KEY (city_id)
#         REFERENCES cities (id) MATCH SIMPLE
#         ON UPDATE NO ACTION ON DELETE NO ACTION
# )
#
# CREATE TABLE cities(
#     id series PRIMARY KEY,
#     name VARCHAR(50) NOT NULL,
#     state_id integer NOT NULL,
#     CONSTRAINT cities_state_id_fkey FOREIGN KEY (state_id)
#         REFERENCES states (id) MATCH SIMPLE
#         ON UPDATE NO ACTION ON DELETE NO ACTION
# )
#
# CREATE TABLE states(
#     id series PRIMARY KEY,
#     name VARCHAR(50) NOT NULL
# )

# %% [markdown]
# Loading data from CSV file

# %%
import pandas as pd
data = pd.read_csv('./superbowl.csv')

# %%
print(data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 10 columns):
# Date          54 non-null object
# SB            54 non-null object
# Winner        54 non-null object
# Winner Pts    54 non-null int64
# Loser         54 non-null object
# Loser Pts     54 non-null int64
# MVP           54 non-null object
# Stadium       54 non-null object
# City          54 non-null object
# State         54 non-null object
# dtypes: int64(2), object(8)
# memory usage: 4.3+ KB
# None

# %%
print(data)
# Out:
#            Date            SB                Winner  Winner Pts  \
# 0    Feb 2 2020      LIV (54)    Kansas City Chiefs          31
# 1    Feb 3 2019     LIII (53)  New England Patriots          13
# 2    Feb 4 2018      LII (52)   Philadelphia Eagles          41
# 3    Feb 5 2017       LI (51)  New England Patriots          34
# 4    Feb 7 2016            50        Denver Broncos          24
# 5    Feb 1 2015     XLIX (49)  New England Patriots          28
# 6    Feb 2 2014   XLVIII (48)      Seattle Seahawks          43
# 7    Feb 3 2013    XLVII (47)      Baltimore Ravens          34
# 8    Feb 5 2012     XLVI (46)       New York Giants          21
# 9    Feb 6 2011      XLV (45)     Green Bay Packers          31
# 10   Feb 7 2010     XLIV (44)    New Orleans Saints          31
# 11   Feb 1 2009    XLIII (43)   Pittsburgh Steelers          27
# 12   Feb 3 2008     XLII (42)       New York Giants          17
# 13   Feb 4 2007      XLI (41)    Indianapolis Colts          29
# 14   Feb 5 2006       XL (40)   Pittsburgh Steelers          21
# 15   Feb 6 2005    XXXIX (39)  New England Patriots          24
# 16   Feb 1 2004  XXXVIII (38)  New England Patriots          32
# 17  Jan 26 2003   XXXVII (37)  Tampa Bay Buccaneers          48
# 18   Feb 3 2002    XXXVI (36)  New England Patriots          20
# 19  Jan 28 2001     XXXV (35)      Baltimore Ravens          34
# 20  Jan 30 2000    XXXIV (34)        St. Louis Rams          23
# 21  Jan 31 1999   XXXIII (33)        Denver Broncos          34
# 22  Jan 25 1998    XXXII (32)        Denver Broncos          31
# 23  Jan 26 1997     XXXI (31)     Green Bay Packers          35
# 24  Jan 28 1996      XXX (30)        Dallas Cowboys          27
# 25  Jan 29 1995     XXIX (29)   San Francisco 49ers          49
# 26  Jan 30 1994   XXVIII (28)        Dallas Cowboys          30
# 27  Jan 31 1993    XXVII (27)        Dallas Cowboys          52
# 28  Jan 26 1992     XXVI (26)   Washington Redskins          37
# 37                      Rose Bowl         Pasadena  California
# 38             Pontiac Silverdome          Pontiac    Michigan
# 39            Louisiana Superdome      New Orleans   Louisiana
# 40                      Rose Bowl         Pasadena  California
# 41                    Orange Bowl            Miami     Florida
# 42                      Superdome      New Orleans   Louisiana
# 43                      Rose Bowl         Pasadena  California
# 44                    Orange Bowl            Miami     Florida
# 45                 Tulane Stadium      New Orleans   Louisiana
# 46                   Rice Stadium          Houston       Texas
# 47              Memorial Coliseum      Los Angeles  California
# 48                 Tulane Stadium      New Orleans   Louisiana
# 49                    Orange Bowl            Miami     Florida
# 50                 Tulane Stadium      New Orleans   Louisiana
# 51                    Orange Bowl            Miami     Florida
# 52                    Orange Bowl            Miami     Florida
# 53              Memorial Coliseum      Los Angeles  California

# %% [markdown]
# After data anaysis, the Nan or NULL values hasn't been spotted, we can insert data to DB

# %%
winners = pd.DataFrame(data['Winner'])
losers = pd.DataFrame(data['Loser'])
team_list = winners.join(losers)
team_list = team_list.stack().reset_index()
team_list = team_list.drop('level_1', 1)
team_list = team_list.drop('level_0', 1)
team_list = team_list.drop_duplicates()
team_list = team_list.reset_index()
team_list = team_list.drop('index', 1)
team_list = team_list.rename(columns={0:'name'})
team_list
# Out:
#                     name
# 0     Kansas City Chiefs
# 1    San Francisco 49ers
# 2   New England Patriots
# 3       Los Angeles Rams
# 4    Philadelphia Eagles
# 5        Atlanta Falcons
# 6         Denver Broncos
# 7      Carolina Panthers
# 8       Seattle Seahawks
# 9       Baltimore Ravens
# 10       New York Giants
# 11     Green Bay Packers
# 12   Pittsburgh Steelers
# 13    New Orleans Saints
# 14    Indianapolis Colts
# 15     Arizona Cardinals
# 16         Chicago Bears
# 17  Tampa Bay Buccaneers
# 18       Oakland Raiders
# 19        St. Louis Rams
# 20      Tennessee Titans
# 21        Dallas Cowboys
# 22    San Diego Chargers
# 23         Buffalo Bills
# 24   Washington Redskins
# 25    Cincinnati Bengals
# 26        Miami Dolphins
# 27   Los Angeles Raiders
# 28     Minnesota Vikings
# 29       Baltimore Colts
# 30         New York Jets

# %%
player_list = pd.DataFrame(data['MVP'])
player_list = player_list.drop_duplicates()
player_list = player_list.reset_index()
player_list = player_list.drop('index', 1)
player_list = player_list.rename(columns={'MVP':'name'})
player_list.index.name = 'id'
player_list
# Out:
#                          name
# id
# 0             Patrick Mahomes
# 1              Julian Edelman
# 2                  Nick Foles
# 3                   Tom Brady
# 4                  Von Miller
# 5               Malcolm Smith
# 6                  Joe Flacco
# 7                 Eli Manning
# 8               Aaron Rodgers
# 9                  Drew Brees
# 10            Santonio Holmes
# 11             Peyton Manning
# 12                 Hines Ward
# 13               Deion Branch
# 14             Dexter Jackson
# 15                 Ray Lewis+
# 16               Kurt Warner+
# 17                John Elway+
# 18             Terrell Davis+
# 19             Desmond Howard
# 20                Larry Brown
# 21               Steve Young+
# 22              Emmitt Smith+
# 23               Troy Aikman+
# 24                Mark Rypien
# 25             Ottis Anderson
# 26               Joe Montana+
# 27                Jerry Rice+
# 28              Doug Williams
# 29                 Phil Simms
# 30              Richard Dent+
# 31              Marcus Allen+
# 32              John Riggins+
# 33               Jim Plunkett
# 34            Terry Bradshaw+
# 35  Harvey MartinRandy White+
# 36          Fred Biletnikoff+
# 37                Lynn Swann+
# 38             Franco Harris+
# 39              Larry Csonka+
# 40                 Jake Scott
# 41            Roger Staubach+
# 42               Chuck Howley
# 43                Len Dawson+
# 44                Joe Namath+
# 45                Bart Starr+

# %%
state_list = pd.DataFrame(data['State'])
state_list = state_list.rename(columns={'State':'name'})
state_list = state_list.drop_duplicates()
state_list = state_list.reset_index()
state_list = state_list.drop('index', 1)
state_list.index.name = 'id'
state_list
# Out:
#           name
# id
# 0      Florida
# 1      Georgia
# 2    Minnesota
# 3        Texas
# 4   California
# 5      Arizona
# 6   New Jersey
# 7    Louisiana
# 8      Indiana
# 9     Michigan

# %%
city_list = pd.DataFrame(data[['City','State']])
city_list = city_list.drop_duplicates()
city_list = city_list.reset_index()
city_list = city_list.drop('index', 1)
city_list = city_list.rename(columns={'City':'name', 'State':'state_id'})
city_list['state_id'] = city_list['state_id'].map(lambda x: state_list[state_list['name'] == x].index.values.astype(int)[0])
city_list.index.name = 'id'
city_list
# Out:
#                name  state_id
# id
# 0     Miami Gardens         0
# 1           Atlanta         1
# 2       Minneapolis         2
# 3           Houston         3
# 4       Santa Clara         4
# 5          Glendale         5
# 6   East Rutherford         6
# 7       New Orleans         7
# 8      Indianapolis         8
# 9         Arlington         3
# 10            Tampa         0
# 11          Detroit         9
# 12     Jacksonville         0
# 13        San Diego         4
# 14            Tempe         5
# 15         Pasadena         4
# 16        Palo Alto         4
# 17          Pontiac         9
# 18            Miami         0
# 19      Los Angeles         4

# %%
stadium_list = pd.DataFrame(data[['Stadium', 'City']], columns=['Stadium','City'])
stadium_list = stadium_list.rename(columns = {'Stadium':'name','City':'city_id'})
stadium_list = stadium_list.drop_duplicates()
stadium_list = stadium_list.reset_index()
stadium_list = stadium_list.drop('index', 1)
stadium_list['city_id'] = stadium_list['city_id'].map(lambda x: city_list[city_list['name'] == x].index.values.astype(int)[0])
stadium_list.index.name = 'id'
stadium_list
# Out:
#                              name  city_id
# id
# 0               Hard Rock Stadium        0
# 1           Mercedes-Benz Stadium        1
# 2               U.S. Bank Stadium        2
# 3                     NRG Stadium        3
# 4                  Levi's Stadium        4
# 5   University of Phoenix Stadium        5
# 6                 MetLife Stadium        6
# 7         Mercedes-Benz Superdome        7
# 8               Lucas Oil Stadium        8
# 9                 Cowboys Stadium        9
# 10               Sun Life Stadium        0
# 11          Raymond James Stadium       10
# 12                Dolphin Stadium        0
# 13                     Ford Field       11
# 14                 Alltel Stadium       12
# 15                Reliant Stadium        3
# 16               Qualcomm Stadium       13
# 17            Louisiana Superdome        7
# 18                   Georgia Dome        1
# 19             Pro Player Stadium        0
# 20              Sun Devil Stadium       14
# 21             Joe Robbie Stadium        0
# 22                      Rose Bowl       15
# 23                      Metrodome        2
# 24                  Tampa Stadium       10
# 25            Jack Murphy Stadium       13
# 26               Stanford Stadium       16
# 27             Pontiac Silverdome       17
# 28                    Orange Bowl       18
# 29                      Superdome        7
# 30                 Tulane Stadium        7
# 31                   Rice Stadium        3
# 32              Memorial Coliseum       19

# %%
game_list = pd.DataFrame(data[['Date', 'SB', 'Winner Pts', 'Loser Pts', 'Winner', 'Loser', 'MVP', 'City', 'Stadium']])
game_list.index.name = 'id'
game_list = game_list.rename(columns={'Winner':'winner_id', 'Loser':'loser_id', 'MVP':'mvp_id', 'City':'city_id', 'Stadium':'stadium_id', 'State':'state_id'})
game_list['winner_id'] = game_list['winner_id'].map(lambda x: team_list[team_list['name'] == x].index.values.astype(int)[0])
game_list['loser_id'] = game_list['loser_id'].map(lambda x: team_list[team_list['name'] == x].index.values.astype(int)[0])
game_list['mvp_id'] = game_list['mvp_id'].map(lambda x: player_list[player_list['name'] == x].index.values.astype(int)[0])
game_list['stadium_id'] = game_list['stadium_id'].map(lambda x: stadium_list[stadium_list['name'] == x].index.values.astype(int)[0])
game_list
# Out:
#            Date            SB  Winner Pts  Loser Pts  winner_id  loser_id  \
# id
# 0    Feb 2 2020      LIV (54)          31         20          0         1
# 1    Feb 3 2019     LIII (53)          13          3          2         3
# 2    Feb 4 2018      LII (52)          41         33          4         2
# 3    Feb 5 2017       LI (51)          34         28          2         5
# 4    Feb 7 2016            50          24         10          6         7
# 5    Feb 1 2015     XLIX (49)          28         24          2         8
# 6    Feb 2 2014   XLVIII (48)          43          8          8         6
# 7    Feb 3 2013    XLVII (47)          34         31          9         1
# 8    Feb 5 2012     XLVI (46)          21         17         10         2
# 9    Feb 6 2011      XLV (45)          31         25         11        12
# 10   Feb 7 2010     XLIV (44)          31         17         13        14
# 11   Feb 1 2009    XLIII (43)          27         23         12        15
# 12   Feb 3 2008     XLII (42)          17         14         10         2
# 13   Feb 4 2007      XLI (41)          29         17         14        16
# 14   Feb 5 2006       XL (40)          21         10         12         8
# 15   Feb 6 2005    XXXIX (39)          24         21          2         4
# 16   Feb 1 2004  XXXVIII (38)          32         29          2         7
# 17  Jan 26 2003   XXXVII (37)          48         21         17        18
# 18   Feb 3 2002    XXXVI (36)          20         17          2        19
# 19  Jan 28 2001     XXXV (35)          34          7          9        10
# 20  Jan 30 2000    XXXIV (34)          23         16         19        20
# 21  Jan 31 1999   XXXIII (33)          34         19          6         5
# 22  Jan 25 1998    XXXII (32)          31         24          6        11
# 23  Jan 26 1997     XXXI (31)          35         21         11         2
# 24  Jan 28 1996      XXX (30)          27         17         21        12
# 25  Jan 29 1995     XXIX (29)          49         26          1        22
# 26  Jan 30 1994   XXVIII (28)          30         13         21        23
# 27  Jan 31 1993    XXVII (27)          52         17         21        23
# 28  Jan 26 1992     XXVI (26)          37         24         24        23
# 29  Jan 27 1991      XXV (25)          20         19         10        23
# 30  Jan 28 1990     XXIV (24)          55         10          1         6
# 31  Jan 22 1989    XXIII (23)          20         16          1        25
# 32  Jan 31 1988     XXII (22)          42         10         24         6
# 33  Jan 25 1987      XXI (21)          39         20         10         6
# 34  Jan 26 1986       XX (20)          46         10         16         2
# 35  Jan 20 1985      XIX (19)          38         16          1        26
# 36  Jan 22 1984    XVIII (18)          38          9         27        24
# 37  Jan 30 1983     XVII (17)          27         17         24        26
# 38  Jan 24 1982      XVI (16)          26         21          1        25
# 39  Jan 25 1981       XV (15)          27         10         18         4
# 40  Jan 20 1980      XIV (14)          31         19         12         3
# 41  Jan 21 1979     XIII (13)          35         31         12        21
# 42  Jan 15 1978      XII (12)          27         10         21         6
# 43   Jan 9 1977       XI (11)          32         14         18        28
# 44  Jan 18 1976        X (10)          21         17         12        21
# 45  Jan 12 1975        IX (9)          16          6         12        28
# 46  Jan 13 1974      VIII (8)          24          7         26        28
# 47  Jan 14 1973       VII (7)          14          7         26        24
# 48  Jan 16 1972        VI (6)          24          3         21        26
# 49  Jan 17 1971         V (5)          16         13         29        21
# 50  Jan 11 1970        IV (4)          23          7          0        28
# 51  Jan 12 1969       III (3)          16          7         30        29
# 52  Jan 14 1968        II (2)          33         14         11        18
# 53  Jan 15 1967         I (1)          35         10         11         0
#
#     mvp_id          city_id  stadium_id
# id
# 0        0    Miami Gardens           0
# 1        1          Atlanta           1
# 2        2      Minneapolis           2
# 3        3          Houston           3
# 4        4      Santa Clara           4
# 5        3         Glendale           5
# 6        5  East Rutherford           6
# 7        6      New Orleans           7
# 8        7     Indianapolis           8
# 9        8        Arlington           9
# 10       9    Miami Gardens          10
# 11      10            Tampa          11
# 12       7         Glendale           5
# 13      11    Miami Gardens          12
# 14      12          Detroit          13
# 15      13     Jacksonville          14
# 16       3          Houston          15
# 17      14        San Diego          16
# 18       3      New Orleans          17
# 19      15            Tampa          11
# 20      16          Atlanta          18
# 21      17    Miami Gardens          19
# 22      18        San Diego          16
# 23      19      New Orleans          17
# 24      20            Tempe          20
# 25      21    Miami Gardens          21
# 26      22          Atlanta          18
# 27      23         Pasadena          22
# 28      24      Minneapolis          23
# 29      25            Tampa          24
# 30      26      New Orleans          17
# 31      27    Miami Gardens          21
# 32      28        San Diego          25
# 33      29         Pasadena          22
# 34      30      New Orleans          17
# 35      26        Palo Alto          26
# 36      31            Tampa          24
# 37      32         Pasadena          22
# 38      26          Pontiac          27
# 39      33      New Orleans          17
# 40      34         Pasadena          22
# 41      34            Miami          28
# 42      35      New Orleans          29
# 43      36         Pasadena          22
# 44      37            Miami          28
# 45      38      New Orleans          30
# 46      39          Houston          31
# 47      40      Los Angeles          32
# 48      41      New Orleans          30
# 49      42            Miami          28
# 50      43      New Orleans          30
# 51      44            Miami          28
# 52      45            Miami          28
# 53      45      Los Angeles          32

# %%
team_list.to_sql('teams', engine, if_exists='append')
player_list.to_sql('players', engine, if_exists='append')
stadium_list.to_sql('stadiums', engine, if_exists='append')
city_list.to_sql('cities', engine, if_exists='append')
state.to_sql('teams', engine, if_exists='append')
game_liststate.to_sql('games', engine, if_exists='append')
